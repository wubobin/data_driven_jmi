# %% [markdown]
# # DFT数据绘画

# %%
#训练集，
import json
with open("/root/workspace/JupyterLab/bandgap-train/json/predicition_DFTBandgap_megnetTrain.json", "r") as f:
    data_train_DFT = json.load(f)

# %%
data_train_DFT[0]
# Out:
# {'structure': {'@module': 'pymatgen.core.structure',
#   '@class': 'Structure',
#   'charge': 0,
#   'lattice': {'matrix': [[19.04630479914883,
#      -0.0040566032990657,
#      -0.1426916443977432],
#     [0.0034609739933677, 6.396748505981273, -0.000509874535366],
#     [0.0926247695841233, -0.0010837160599577, 6.136512868775321]],
#    'pbc': [True, True, True],
#    'a': 19.046839734283772,
#    'b': 6.396749462585406,
#    'c': 6.137211965626259,
#    'alpha': 90.01421592599021,
#    'beta': 89.56448086220985,
#    'gamma': 89.981169536675,
#    'volume': 747.7231178217681},
#   'properties': {},
#   'sites': [{'species': [{'element': 'H', 'occu': 1}],
#     'abc': [0.1107547927844606, 0.4996111077208065, 0.3119039750630436],
#     'xyz': [2.1400887162126123, 3.195099303279981, 1.897944234307785],
#     'properties': {},
#     'label': 'H'},
#    {'species': [{'element': 'H', 'occu': 1}],
#     'abc': [0.444095222460228, 0.4994564093102785, 0.312729559099898],
# ...

# %%
len(data_train_DFT)
# Out:
# 90

# %%
#赋值
y_trainDFTbandgaps = []

for item in data_train_DFT:
    pred_bandgap = item['prediction_DFTgaps']
    y_trainDFTbandgaps.append(pred_bandgap)
len(y_trainDFTbandgaps)
# Out:
# 90

# %%
#测试集，
import json
with open("/root/workspace/JupyterLab/bandgap-train/json/predicition_DFTBandgap_megnetTest.json", "r") as f:
    data_test_DFT = json.load(f)

# %%
len(data_test_DFT)
# Out:
# 18

# %%
data_test_DFT[0]
# Out:
# {'structure': {'@module': 'pymatgen.core.structure',
#   '@class': 'Structure',
#   'charge': 0,
#   'lattice': {'matrix': [[18.785153738121476, 1.2698671e-08, 2.0787912116e-06],
#     [1.933054958e-07, 6.401154116279119, 7.88186326e-08],
#     [8.2022211e-09, 1.7309947e-09, 6.401153507054056]],
#    'pbc': [True, True, True],
#    'a': 18.785153738121593,
#    'b': 6.4011541162791215,
#    'c': 6.401153507054056,
#    'alpha': 89.99999927901224,
#    'beta': 89.99999358615256,
#    'gamma': 89.99999823101948,
#    'volume': 769.7173560999125},
#   'properties': {},
#   'sites': [{'species': [{'element': 'Cs', 'occu': 1}],
#     'abc': [0.1666666699999979, 0.5, 0.5],
#     'xyz': [3.130859119724578, 3.200577061121502, 3.2005771394015534],
#     'properties': {},
#     'label': 'Cs'},
#    {'species': [{'element': 'Cs', 'occu': 1}],
#     'abc': [0.4999682151334189, 0.4999999999999817, 0.5000000099999369],
#     'xyz': [9.391979886209324, 3.2005770653538717, 3.2005778962770073],
# ...

# %%
#赋值
y_testDFTbandgaps = []

for item in data_test_DFT:
    pred_bandgap = item['prediction_DFTgaps']
    y_testDFTbandgaps.append(pred_bandgap)
len(y_testDFTbandgaps)
# Out:
# 18

# %%
#真实值赋值
with open("/root/workspace/JupyterLab/bandgap-train/json/predicition_results_megnetGapTrain.json", "r") as f:
    data_train_realDFT = json.load(f)

# %%
data_train_realDFT[0]
# Out:
# {'structure': {'@module': 'pymatgen.core.structure',
#   '@class': 'Structure',
#   'charge': 0,
#   'lattice': {'matrix': [[19.04630479914883,
#      -0.0040566032990657,
#      -0.1426916443977432],
#     [0.0034609739933677, 6.396748505981273, -0.000509874535366],
#     [0.0926247695841233, -0.0010837160599577, 6.136512868775321]],
#    'pbc': [True, True, True],
#    'a': 19.046839734283772,
#    'b': 6.396749462585406,
#    'c': 6.137211965626259,
#    'alpha': 90.01421592599021,
#    'beta': 89.56448086220985,
#    'gamma': 89.981169536675,
#    'volume': 747.7231178217681},
#   'properties': {},
#   'sites': [{'species': [{'element': 'H', 'occu': 1}],
#     'abc': [0.1107547927844606, 0.4996111077208065, 0.3119039750630436],
#     'xyz': [2.1400887162126123, 3.195099303279981, 1.897944234307785],
#     'properties': {},
#     'label': 'H'},
#    {'species': [{'element': 'H', 'occu': 1}],
#     'abc': [0.444095222460228, 0.4994564093102785, 0.312729559099898],
# ...

# %%
len(data_train_realDFT)
# Out:
# 90
